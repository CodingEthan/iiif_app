# %%
import pytesseract
from PIL import Image
from io import BytesIO
import requests

# def OCR_demo(file_path):
#     # 导入OCR安装路径，如果设置了系统环境，就可以不用设置了
#     pytesseract.pytesseract.tesseract_cmd = r"D:\App\Tesseract-OCR\tesseract.exe"
#     # 打开要识别的图片

#     image = Image.open(file_path)
#     # 使用pytesseract调用image_to_string方法进行识别，传入要识别的图片，lang='chi_sim'是设置为中文识别，
#     text = pytesseract.image_to_boxes(image, lang='chi_sim')
#     result = [word.split() for word in text.split("\n")]
#     print(result)
url = "http://dh.usources.cn:9002/iiif/zhaomengfushouchuntang.tif/full/,150/0/default.jpg"
response = requests.get(url)
image = Image.open(BytesIO(response.content))
text = pytesseract.image_to_string(image, lang='chi_sim')
print(text)
# Out:
# 六 婉消和桂隐二训流岂如不度术呆巴间巴度全可兰志徽望旺之大永嘉这才
#
# 国制炎 和上上葵夏口用 时洗是 能总私下是箱 由mi已畸善可 已蛙包晨其知移所生之兰值祝志扫把平外 0  人竹旦少 本Fr<内 能外后 案左人 家身当六始之 长盟之 之酝之 内杖父 数理才 杰z<吉做然 = 敌芝用 未是监 洋何人 赔不 合并厦刘特震 卑非之午芭瑶 并年日 属客贡 避风山 日采"1 除为
#
# 淆 央训胡 基未林 四常东 在姓知之茂银加昌之人向洋广人贞当之且站沦 灰世长 向起聊志知癌尼党后清忆二 并徐如合言主天  子扎 事吾年 意自天杨儿可滋夕情 春喜冶齐遍伴 彰县启 闻娩靠近其老 之拖光 党豚豆 如如然 斯生年 兵数原风日日 恩自十 三攻用 战思之 区w厌 于钊世 一床莘 吉P。 寄衣年胸肯徐可末 条导枕徐防闯清 陂攻忆王不小识菠三 然右流见无后湖移在溪湖里平福春
# 是人                               0 名此以看必2而和和证何民太囊 力员准 呈时阅夺上上孔 语其5。 7日攻 若在由 良生玫 羊十隆 蛙放天 谓你由 凌余谨农是意 吹是也 一图考 身强委 问相落 合局庭削年富 慢香植 捧之橡检2*汉池如烷 续雍 大往关间旋吾在二隐震省不其西狂箱之乙党
# 多    学                                                    痢之堂藉洗别 币旺各 固向县音平租 很过录入卖 : 生全酒,估西长 供雇洋 奉责 : 甸日卖不年作清詹窗 时党危 而可里民普不 蝇名得 家门送之少澳 再且过 财加能隆三可闻竺前 球原桶重训依六也如简给中攀之"1作抢及沪 -有在得箭对里上月外记
#
# 矢知访   集且 镶源汀 示者非生先言也痒行多电食
#        刀畦钴程玉关目训认县天刀剑者险 大革着居事筑切之站 必部生涯各六 着可穆食事之除值茶平等合法过赛视得运 之知瑟

# %%
OCR_demo(r'C:\Users\WYJ20\OneDrive\桌面\iiif_app\app\static\img\R.jpg')
# Out:
# [['喜', '146', '377', '170', '403', '0'], ['欢', '175', '377', '395', '403', '0'], ['璀', '217', '366', '242', '409', '0'], ['天', '241', '366', '263', '409', '0'], ['大', '262', '366', '288', '409', '0'], ['达', '287', '366', '320', '409', '0'], ['的', '319', '366', '352', '409', '0'], ['棉', '351', '366', '379', '409', '0'], ['争', '378', '366', '398', '409', '0'], ['喜', '146', '328', '170', '354', '0'], ['欢', '175', '328', '395', '354', '0'], ['虱', '212', '318', '242', '360', '0'], ['街', '241', '318', '274', '360', '0'], ['起', '273', '318', '297', '360', '0'], ['束', '296', '318', '326', '360', '0'], ['的', '325', '318', '355', '360', '0'], ['火', '354', '318', '381', '360', '0'], ['锅', '380', '318', '400', '360', '0'], ['总', '146', '279', '182', '305', '0'], ['欢', '182', '282', '198', '303', '0'], ['万', '212', '280', '225', '300', '0'], ['物', '239', '280', '253', '301', '0'], ['罕', '269', '279', '282', '304', '0'], ['静', '294', '278', '311', '304', '0'], ['的', '324', '280', '337', '303', '0'
# ...

# %%
Image.open('../static/img/微信截图_20230308200702.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=985x248>

# %%
from iiif_prezi3 import Manifest, create_canvas_from_iiif

help(Manifest)
# help(create_canvas_from_iiif.CreateCanvasFromIIIF())
# canvas = create_canvas_from_iiif.CreateCanvasFromIIIF()
# canvas.create_canvas_from_iiif("https://iiif.harvardartmuseums.org/manifests/object/299843/canvas/canvas-4968438", label={"en": ["%s" %text]}, height=3000, width=4000)
# Out:
# Help on class Manifest in module iiif_prezi3.skeleton:
#
# class Manifest(Class, iiif_prezi3.helpers.add_item.AddItem, iiif_prezi3.helpers.add_label.AddLabel, iiif_prezi3.helpers.add_metadata.AddMetadata, iiif_prezi3.helpers.add_range.AddRange, iiif_prezi3.helpers.add_service.AddService, iiif_prezi3.helpers.annotation_helpers.AnnotationHelpers, iiif_prezi3.helpers.canvas_sizes.MaxHelper, iiif_prezi3.helpers.canvas_sizes.MinHelper, iiif_prezi3.helpers.create_canvas_from_iiif.CreateCanvasFromIIIF, iiif_prezi3.helpers.make_canvas.MakeCanvas, iiif_prezi3.helpers.make_range.MakeRange, iiif_prezi3.helpers.make_service.MakeService, iiif_prezi3.helpers.to_reference.ToReference)
# ...

# %%
# from iiif import Manifest, ImageContent, ImageService, Canvas, Sequence, Annotation, AnnotationList, Range, Service, Choice, Rendering, Thumbnail, Linking, Rights, Logo, seeAlso, within, start, end, duration, body, target, motivation, format, styleClass, service, profile, width, height, duration, startCanvas, behavior, viewingDirection, viewingHint, navDate, language, value, label, metadata, attribution, license, logo, related,
import iiif_prezi3
from iiif_prezi3 import make_manifest,add_item,Manifest,auto_fields
# help(iiif_prezi3)
help(iiif_prezi3)
# # 创建 Manifest 对象
# manifest = Manifest()
# manifest.set_id('http://example.com/manifest.json')
# manifest.set_label('Example Manifest')

# # 创建序列 Sequence 对象
# sequence = manifest.add_sequence()
# sequence.set_label('Example Sequence')

# # 创建第一个 Canvas 对象
# canvas1 = sequence.add_canvas()
# canvas1.set_id('http://example.com/canvas/1')
# canvas1.set_label('Example Canvas 1')

# # 添加第一个 Canvas 的图像资源
# image1 = ImageContent()
# image1.set_id('http://example.com/image/1')
# image1.set_format('image/jpeg')
# image1.set_width(1000)
# image1.set_height(800)

# # 添加第一个 Canvas 的 ImageService
# service1 = ImageService()
# service1.set_id('http://example.com/image/1/full/full/0/default.jpg')
# service1.set_width(1000)
# service1.set_height(800)
# image1.set_service(service1)

# canvas1.set_image(image1)

# # 创建第二个 Canvas 对象
# canvas2 = sequence.add_canvas()
# canvas2.set_id('http://example.com/canvas/2')
# canvas2.set_label('Example Canvas 2')

# # 添加第二个 Canvas 的图像资源
# image2 = ImageContent()
# image2.set_id('http://example.com/image/2')
# image2.set_format('image/jpeg')
# image2.set_width(1200)
# image2.set_height(900)

# # 添加第二个 Canvas 的 ImageService
# service2 = ImageService()
# service2.set_id('http://example.com/image/2/full/full/0/default.jpg')
# service2.set_width(1200)
# service2.set_height(900)
# image2.set_service(service2)

# canvas2.set_image(image2)

# # 将 Manifest 对象转换为 JSON 格式
# manifest_data = manifest.to_json()

# # 输出 Manifest JSON 数据
# print(manifest_data)
# Out:
# Help on package iiif_prezi3:
#
# NAME
#     iiif_prezi3
#
# PACKAGE CONTENTS
#     base
#     config (package)
#     extensions (package)
#     helpers (package)
#     loader
#     skeleton
#
# SUBMODULES
#     add_item
#     add_label
#     add_metadata
#     add_range
#     add_service
#     annotation_helpers
#     auto_fields
#     canvas_helpers
#     canvas_sizes
#     create_canvas_from_iiif
#     make_canvas
#     make_collection
#     make_manifest
#     make_range
#     make_service
#     set_hwd
#     set_hwd_from_file
#     set_hwd_from_iiif
#     to_reference
#
# DATA
#     Any = typing.Any
#         Special type indicating an unconstrained type.
#
#         - Any is compatible with every type.
#         - Any assumed to have all methods.
#         - All values assumed to be instances of Any.
#
#         Note that all the above statements are true from the point of view of
#         static type checkers. At runtime, Any should not be used with instance
# ...

# %%
import iiif
from iiif import request
help(request)
# Out:
# Help on module iiif.request in iiif:
#
# NAME
#     iiif.request - Create and parse IIIF request URLs.
#
# DESCRIPTION
#     This class is a thorough implementation of restrictions in the
#     IIIF specification. It does not add any implementation specific
#     restrictions.
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         IIIFRequestBaseURI
#     builtins.object
#         IIIFRequest
#     iiif.error.IIIFError(builtins.Exception)
#         IIIFRequestError
#             IIIFRequestPathError
#
#     class IIIFRequest(builtins.object)
#      |  IIIFRequest(api_version='2.1', baseurl='', allow_slashes_in_identifier=False, **params)
#      |
#      |  Implement IIIF request URL syntax.
#      |
#      |  There are two URL forms defined in section 2:
#      |  http[s]://server/[prefix/]identifier/region/size/rotation/quality[.format]
#      |  or
#      |  http[s]://server/[prefix/]identifier/info.format
#      |
# ...

# %%
import openai

# 输入你的 api_key
chat_gpt_key = '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'
# 将 Key 进行传入
openai.api_key = chat_gpt_key


def completion(prompt):
    response = openai.Completion.create(
        # text-davinci-003 是指它的模型
        model="text-davinci-003",
        prompt=prompt,
        temperature=0.5,
        max_tokens=1024,
        n=1,
        stop=None
    )
    message = response.choices[0].text
    return message

print(completion(input("在这里输入你想对chatgpt说的话，然后它就会给出答案：")))
# Out:
# 我是一个学生。

# %%
from app.models.ocr_list import OCR_demo as ocr 
ocr("app\static\img\微信截图_20230308200702.png")
# Out:
# '名险\nKL>\n\n青本起始页遇到了一些问题.…\n'

# %%
import pytesseract
from PIL import Image
from io import BytesIO
import requests

# def OCR_demo(file_path):
#     # 导入OCR安装路径，如果设置了系统环境，就可以不用设置了
#     pytesseract.pytesseract.tesseract_cmd = r"D:\App\Tesseract-OCR\tesseract.exe"
#     # 打开要识别的图片

#     image = Image.open(file_path)
#     # 使用pytesseract调用image_to_string方法进行识别，传入要识别的图片，lang='chi_sim'是设置为中文识别，
#     text = pytesseract.image_to_boxes(image, lang='chi_sim')
#     result = [word.split() for word in text.split("\n")]
#     print(result)
image = Image.open(r"C:\Users\WYJ20\Downloads\ff2aca2b21e2d9f6227cd9148283e323.jpeg")
text = pytesseract.image_to_string(image, lang='chi_sim')
print(text)
# Out:
# 应是天仙狂醉，乱把白云揉碎。
#
# 一一李白《清平乐》

# %%
from cnocr import CnOcr
from PIL import Image

img_fp = r'D:\大创\大创IIIF实践\iiif_app\app\static\img\be9f9b4d-c716-4609-8619-4c3f06bc9104.jpg'
image = Image.open(r"C:\Users\WYJ20\Downloads\ff2aca2b21e2d9f6227cd9148283e323.jpeg")
ocr = CnOcr(rec_model_name='ch_PP-OCRv3')
out = ocr.ocr(image)
result = ''
for x in out:
    result += x["text"]
    result += "\n"
print(result)
# Out:
# 是天仙狂醉，乱把白揉碎。
# 一李白《清平乐》

# %%
try:
    print("qian")
    b=1
    a=b
    print("hou")
except:
    print("except")
# Out:
# qian
# hou

# %%
import requests


image_fp = r"D:\大创\大创IIIF实践\iiif_app\app\static\img\be9f9b4d-c716-4609-8619-4c3f06bc9104.jpg"
r = requests.post(
    'http://0.0.0.0:8501/ocr', files={'image': (image_fp, open(image_fp, 'rb'), 'image/jpg')},
)
ocr_out = r.json()['results']
print(ocr_out)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# d:\App\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# d:\App\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# d:\App\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# OSError: [WinError 10049] 在其上下文中，该请求的地址无效。
#
# During handling of the above exception, another exception occurred:
#
# ...
